# %%
import pandas as pd
import numpy as np

# %%
df =pd.read_csv('Perovskite_database_content_all_data.csv')
# Out:
# C:\Users\yiru\AppData\Local\Temp\ipykernel_16272\3219310303.py:1: DtypeWarning: Columns (10,22,29,31,32,35,36,40,44,45,46,48,51,54,65,84,89,90,93,98,99,100,105,108,115,118,122,123,125,130,134,138,142,143,144,146,149,152,163,166,167,171,172,173,175,178,181,192,194,225,271,272,273,277,304,315,321,325,330,331,335,336,342,348,369,371,373,374,376,380,384,387,403,405,407,409) have mixed types. Specify dtype option on import or set low_memory=False.
#   df =pd.read_csv('Perovskite_database_content_all_data.csv')

# %%
print(df)
# Out:
#        Ref_ID  Ref_ID_temp Ref_name_of_person_entering_the_data  \
# 0           1            1                       Adam Hultqvist
# 1           2            2                       Adam Hultqvist
# 2           3            3                       Adam Hultqvist
# 3           4            4                       Adam Hultqvist
# 4           5            5                       Adam Hultqvist
# ...       ...          ...                                  ...
# 42492   42497           37                      Timothy Siegler
# 42493   42485           25                      Timothy Siegler
# 42494   42488           28                      Timothy Siegler
# 42495   42491           31                      Timothy Siegler
# 42496   42472           12                                  NaN
#
#        Ref_data_entered_by_author          Ref_DOI_number  Ref_lead_author  \
# 0                           False       10.1021/jp5126624     Sabba et al.
# ...

# %%
df
# Out:
#        Ref_ID  Ref_ID_temp Ref_name_of_person_entering_the_data  \
# 0           1            1                       Adam Hultqvist
# 1           2            2                       Adam Hultqvist
# 2           3            3                       Adam Hultqvist
# 3           4            4                       Adam Hultqvist
# 4           5            5                       Adam Hultqvist
# ...       ...          ...                                  ...
# 42492   42497           37                      Timothy Siegler
# 42493   42485           25                      Timothy Siegler
# 42494   42488           28                      Timothy Siegler
# 42495   42491           31                      Timothy Siegler
# 42496   42472           12                                  NaN
#
#        Ref_data_entered_by_author          Ref_DOI_number  Ref_lead_author  \
# 0                           False       10.1021/jp5126624     Sabba et al.
# ...

# %%
df.shape
# Out:
# (42497, 410)

# %%
df.head()
# Out:
#    Ref_ID  Ref_ID_temp Ref_name_of_person_entering_the_data  \
# 0       1            1                       Adam Hultqvist
# 1       2            2                       Adam Hultqvist
# 2       3            3                       Adam Hultqvist
# 3       4            4                       Adam Hultqvist
# 4       5            5                       Adam Hultqvist
#
#    Ref_data_entered_by_author     Ref_DOI_number Ref_lead_author  \
# 0                       False  10.1021/jp5126624    Sabba et al.
# 1                       False  10.1021/jp5126624    Sabba et al.
# 2                       False  10.1021/jp5126624    Sabba et al.
# 3                       False  10.1021/jp5126624    Sabba et al.
# 4                       False  10.1021/jp5126624    Sabba et al.
#
#   Ref_publication_date                          Ref_journal  \
# 0           2015-01-06  The Journal of Physical Chemistry C
# 1           2015-01-06  The Journal of Physical Chemistry C
# ...

# %%
df.tail(10)
# Out:
#        Ref_ID  Ref_ID_temp Ref_name_of_person_entering_the_data  \
# 42487   42467            7                      Timothy Siegler
# 42488   42470           10                      Timothy Siegler
# 42489   42475           15                      Timothy Siegler
# 42490   42502           42                      Timothy Siegler
# 42491   42495           35                      Timothy Siegler
# 42492   42497           37                      Timothy Siegler
# 42493   42485           25                      Timothy Siegler
# 42494   42488           28                      Timothy Siegler
# 42495   42491           31                      Timothy Siegler
# 42496   42472           12                                  NaN
#
#        Ref_data_entered_by_author          Ref_DOI_number  Ref_lead_author  \
# 42487                        True  10.1021/acsaem.9b01298  Siegler et. al.
# 42488                        True  10.1021/acsaem.9b01298  Siegler et. al.
# ...

# %%
pd.options.display.max_columns = None

# %%
df.head(3)
# Out:
#    Ref_ID  Ref_ID_temp Ref_name_of_person_entering_the_data  \
# 0       1            1                       Adam Hultqvist
# 1       2            2                       Adam Hultqvist
# 2       3            3                       Adam Hultqvist
#
#    Ref_data_entered_by_author     Ref_DOI_number Ref_lead_author  \
# 0                       False  10.1021/jp5126624    Sabba et al.
# 1                       False  10.1021/jp5126624    Sabba et al.
# 2                       False  10.1021/jp5126624    Sabba et al.
#
#   Ref_publication_date                          Ref_journal  \
# 0           2015-01-06  The Journal of Physical Chemistry C
# 1           2015-01-06  The Journal of Physical Chemistry C
# 2           2015-01-06  The Journal of Physical Chemistry C
#
#    Ref_part_of_initial_dataset       Ref_original_filename_data_upload  \
# 0                         True  Historic dataset on 2020 11 22_v7.xlsx
# ...

# %%
data =df[['Perovskite_composition_a_ions','Perovskite_composition_a_ions_coefficients','Perovskite_composition_b_ions','Perovskite_composition_c_ions','Perovskite_composition_c_ions_coefficients','Perovskite_deposition_thermal_annealing_temperature','Perovskite_deposition_thermal_annealing_time','ETL_stack_sequence','ETL_thickness','HTL_stack_sequence','HTL_additives_compounds','Perovskite_deposition_solvents','JV_default_PCE']]

# %%
data
# Out:
#       Perovskite_composition_a_ions  \
# 0                                Cs
# 1                                Cs
# 2                                Cs
# 3                                Cs
# 4                                Cs
# ...                             ...
# 42492                            MA
# 42493                            MA
# 42494                            MA
# 42495                            MA
# 42496                           NaN
#
#       Perovskite_composition_a_ions_coefficients  \
# 0                                              1
# 1                                              1
# 2                                              1
# 3                                              1
# 4                                              1
# ...                                          ...
# 42492                                        1.0
# 42493                                        1.0
# 42494                                        1.0
# ...

# %%
import matplotlib.pyplot as plt

# %%
x = data['Perovskite_deposition_thermal_annealing_temperature']

# %%
#x.fillna(0,inplace=True)
# Out:
# C:\Users\yiru\AppData\Local\Temp\ipykernel_16272\3057059380.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x.fillna(0,inplace=True)

# %%
x
# Out:
# 0            100
# 1            100
# 2            100
# 3            100
# 4            100
#           ...
# 42492        100
# 42493        100
# 42494        100
# 42495        100
# 42496    Unknown
# Name: Perovskite_deposition_thermal_annealing_temperature, Length: 42497, dtype: object

# %%
y = data['JV_default_PCE']

# %%
y.fillna(0,inplace=True)
# Out:
# C:\Users\yiru\AppData\Local\Temp\ipykernel_16272\2540808179.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y.fillna(0,inplace=True)

# %%
y
# Out:
# 0        0.00
# 1        0.00
# 2        0.13
# 3        0.12
# 4        0.10
#          ...
# 42492    1.08
# 42493    1.61
# 42494    1.61
# 42495    2.00
# 42496    0.00
# Name: JV_default_PCE, Length: 42497, dtype: float64

# %%
plt.scatter(x,y)

# %%
x = data['Perovskite_deposition_thermal_annealing_time']

# %%
plt.scatter(x,y)

# %%
data1 = data.replace('Sn',0.1)
data1
# Out:
#       Perovskite_composition_a_ions  \
# 0                                Cs
# 1                                Cs
# 2                                Cs
# 3                                Cs
# 4                                Cs
# ...                             ...
# 42492                            MA
# 42493                            MA
# 42494                            MA
# 42495                            MA
# 42496                           NaN
#
#       Perovskite_composition_a_ions_coefficients  \
# 0                                              1
# 1                                              1
# 2                                              1
# 3                                              1
# 4                                              1
# ...                                          ...
# 42492                                        1.0
# 42493                                        1.0
# 42494                                        1.0
# ...
